# %%
import pandas as pd #libreria que se utiliza para el manejo de datos
import seaborn as sns #libreria utilizada para la construción de gráficos

# %%
X=pd.read_csv('capecsi.csv', sep=';') #Se asigna a la variable X la base de datos

# %%
sns.clustermap(X) # Se crea el cluster desde los varlores de la base de datos
